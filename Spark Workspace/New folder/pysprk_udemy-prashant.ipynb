# %% [markdown]
# **Introduction of Hadoop**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The main components of Hadoop ( distributed platform for data processing ) :
#
#
# *   YARN -> resource management
# *   HDFS -> storage management
# *   MAP REDUCE -> data processing

# %% [markdown]
# ***MAP REDUCE WORKING CONCEPT:***
#
# *   it is difficult to get total line count from a 20TB file
# *   strorage + processing problem, will take days to complete the task
# *   mapper will break this file into cmaller blocks and store it to multiple data nodes and compute line count paralley
# *   Reducer collect the values and return the result

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***What is Data Lake?***

# %% [markdown]
# ![image.png](data:image/png;base64,...)
